# %%
import os

for file in sorted(os.listdir()):
    if file.endswith(".csv"):
        print(file)

# %% [markdown]
# # ECOWAS Border Trade Intelligence and Analytics
#
# # Power BI Dashboard Development Guide
#
# ## Objective
#
# This notebook explains how to build an interactive Power BI dashboard using the datasets prepared in Notebook 05.
#
# The dashboard is intended for executive decision-makers and will present key indicators, operational performance, trade trends, and border intelligence through interactive visualizations.

# %% [markdown]
# # Dashboard Overview
#
# The dashboard consists of four interactive pages:
#
# 1. Executive Overview
# 2. Border Operations
# 3. Trade Analysis
# 4. Security & Risk Analysis
#
# Each page focuses on a different aspect of border management while allowing users to filter and explore the data interactively.

# %% [markdown]
# # Import Data
#
# Open Microsoft Power BI Desktop.
#
# Select:
#
# Home → Get Data → Text/CSV
#
# Import the following files:
#
# - fact_transactions.csv
# - dim_date.csv
# - dim_border.csv
# - dim_country.csv
# - dim_commodity.csv
#
# Click **Load** after selecting the files.

# %% [markdown]
# # Data Model
#
# Create the following relationships:
#
# fact_transactions[Transaction_Date] → dim_date[Date]
#
# fact_transactions[Border_Post] → dim_border[Border_Post]
#
# fact_transactions[Commodity] → dim_commodity[Commodity]
#
# fact_transactions[Entry_Country] → dim_country[Entry_Country]
#
# Ensure the relationships are **One-to-Many**, with the dimension tables on the "One" side.

# %% [markdown]
# # Executive Dashboard
#
# Create KPI Cards for:
#
# - Total Transactions
# - Total Trade Value
# - Total Revenue
# - Average Queue Length
# - Average Processing Time
# - Average Border Efficiency Score
